# %%
import pandas as pd
from plotnine import *

# %%
# %%sh
# pip install plotnine
# Out:
# ...
#   Using cached plotnine-0.10.1-py3-none-any.whl (1.2 MB)
# ...
#   Using cached mizani-0.8.1-py3-none-any.whl (64 kB)
# ...
#   Using cached palettable-3.3.0-py2.py3-none-any.whl (111 kB)
# ...

# %% [markdown]
# ## Reading in data as pandas dataframe
# Check out how to use the pandas library [here](https://www.w3schools.com/python/pandas/default.asp)!

# %%
df = pd.read_csv("/Users/ktian/DataCo-Analysis/Data/DataCoSupplyChainDataset.csv", encoding = "unicode_escape")

# %%
display(df)
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...
